# %%
import numpy as np
import pandas as pd
from transformers import pipeline,DistilBertTokenizerFast
import requests
from bs4 import BeautifulSoup,NavigableString
import os
import hashlib
from nltk.corpus import cmudict
import string
import nltk
nltk.download()
from nltk.tokenize import word_tokenize
import openpyxl
import re
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q

# %%
dataset=pd.read_excel('/content/Input.xlsx')
l=[]
for i in dataset['URL']:
  l.append(i)
l.insert(0,0)

# %%
len(l)
# Out:
# 101

# %%
def extract(url):
  response =requests.get(url)
  if response.status_code==200:
    soup=BeautifulSoup(response.text,'html.parser')
    elements=soup.find('div',class_='td-post-content tagdiv-type')
    if elements:
      for tag in elements.find(['p', 'strong', 'u','ol']):
        if not isinstance(tag,NavigableString):
          tag.unwrap()
      clean_elements=elements.get_text(strip=True)
      return clean_elements
  else:
    print("didnt worked")
    return "NULL"

# %%
def process_input_file(input_file_path, output_folder):
  workbook = openpyxl.load_workbook(input_file_path)
  sheet = workbook.active
  for row in sheet.iter_rows(min_row=2, values_only=True):
    url_id, url = row
    extracted_text = extract(url)
    if extracted_text:
        filename = f"{url_id}.txt"
        filepath = os.path.join(output_folder, filename)
        with open(filepath, 'w', encoding='utf-8') as output_file:
            output_file.write(extracted_text)
        print(f'Text extracted for URL ID {url_id} and saved to {filename}')
    else:
        filename = f"{url_id}.txt"
        filepath = os.path.join(output_folder, filename)
        with open(filepath, 'w', encoding='utf-8') as output_file:
            output_file.write("NULL")
        print(f'Text extracted for URL ID {url_id} and saved to {filename}')
  workbook.close()
input_file_path = '/content/Input.xlsx'  # Replace with the path to your input file
output_folder = '/content/sample_data/output_folder'  # Replace with your desired output folder

process_input_file(input_file_path, output_folder)
# Out:
# Text extracted for URL ID blackassign0001 and saved to blackassign0001.txt
# Text extracted for URL ID blackassign0002 and saved to blackassign0002.txt
# Text extracted for URL ID blackassign0003 and saved to blackassign0003.txt
# Text extracted for URL ID blackassign0004 and saved to blackassign0004.txt
# Text extracted for URL ID blackassign0005 and saved to blackassign0005.txt
# Text extracted for URL ID blackassign0006 and saved to blackassign0006.txt
# Text extracted for URL ID blackassign0007 and saved to blackassign0007.txt
# Text extracted for URL ID blackassign0008 and saved to blackassign0008.txt
# Text extracted for URL ID blackassign0009 and saved to blackassign0009.txt
# Text extracted for URL ID blackassign0010 and saved to blackassign0010.txt
# Text extracted for URL ID blackassign0011 and saved to blackassign0011.txt
# Text extracted for URL ID blackassign0012 and saved to blackassign0012.txt
# Text extracted for URL ID blackassign0013 and saved to blackassign0013.txt
# Text extracted for URL ID blackassign0014 and saved to blackassign0014.txt
# Text extracted for URL ID blackassign0015 and saved to blackassign0015.txt
# Text extracted for URL ID blackassign0016 and saved to blackassign0016.txt
# Text extracted for URL ID blackassign0017 and saved to blackassign0017.txt
# Text extracted for URL ID blackassign0018 and saved to blackassign0018.txt
# Text extracted for URL ID blackassign0019 and saved to blackassign0019.txt
# Text extracted for URL ID blackassign0020 and saved to blackassign0020.txt
# Text extracted for URL ID blackassign0021 and saved to blackassign0021.txt
# Text extracted for URL ID blackassign0022 and saved to blackassign0022.txt
# Text extracted for URL ID blackassign0023 and saved to blackassign0023.txt
# Text extracted for URL ID blackassign0024 and saved to blackassign0024.txt
# Text extracted for URL ID blackassign0025 and saved to blackassign0025.txt
# Text extracted for URL ID blackassign0026 and saved to blackassign0026.txt
# Text extracted for URL ID blackassign0027 and saved to blackassign0027.txt
# Text extracted for URL ID blackassign0028 and saved to blackassign0028.txt
# Text extracted for URL ID blackassign0029 and saved to blackassign0029.txt
# Text extracted for URL ID blackassign0030 and saved to blackassign0030.txt
# Text extracted for URL ID blackassign0031 and saved to blackassign0031.txt
# Text extracted for URL ID blackassign0032 and saved to blackassign0032.txt
# Text extracted for URL ID blackassign0033 and saved to blackassign0033.txt
# Text extracted for URL ID blackassign0034 and saved to blackassign0034.txt
# Text extracted for URL ID blackassign0035 and saved to blackassign0035.txt
# didnt worked
# Text extracted for URL ID blackassign0036 and saved to blackassign0036.txt
# Text extracted for URL ID blackassign0037 and saved to blackassign0037.txt
# Text extracted for URL ID blackassign0038 and saved to blackassign0038.txt
# Text extracted for URL ID blackassign0039 and saved to blackassign0039.txt
# Text extracted for URL ID blackassign0040 and saved to blackassign0040.txt
# Text extracted for URL ID blackassign0041 and saved to blackassign0041.txt
# Text extracted for URL ID blackassign0042 and saved to blackassign0042.txt
# Text extracted for URL ID blackassign0043 and saved to blackassign0043.txt
# Text extracted for URL ID blackassign0044 and saved to blackassign0044.txt
# Text extracted for URL ID blackassign0045 and saved to blackassign0045.txt
# Text extracted for URL ID blackassign0046 and saved to blackassign0046.txt
# Text extracted for URL ID blackassign0047 and saved to blackassign0047.txt
# Text extracted for URL ID blackassign0048 and saved to blackassign0048.txt
# didnt worked
# Text extracted for URL ID blackassign0049 and saved to blackassign0049.txt
# Text extracted for URL ID blackassign0050 and saved to blackassign0050.txt
# Text extracted for URL ID blackassign0051 and saved to blackassign0051.txt
# Text extracted for URL ID blackassign0052 and saved to blackassign0052.txt
# Text extracted for URL ID blackassign0053 and saved to blackassign0053.txt
# Text extracted for URL ID blackassign0054 and saved to blackassign0054.txt
# Text extracted for URL ID blackassign0055 and saved to blackassign0055.txt
# Text extracted for URL ID blackassign0056 and saved to blackassign0056.txt
# Text extracted for URL ID blackassign0057 and saved to blackassign0057.txt
# Text extracted for URL ID blackassign0058 and saved to blackassign0058.txt
# Text extracted for URL ID blackassign0059 and saved to blackassign0059.txt
# Text extracted for URL ID blackassign0060 and saved to blackassign0060.txt
# Text extracted for URL ID blackassign0061 and saved to blackassign0061.txt
# Text extracted for URL ID blackassign0062 and saved to blackassign0062.txt
# Text extracted for URL ID blackassign0063 and saved to blackassign0063.txt
# Text extracted for URL ID blackassign0064 and saved to blackassign0064.txt
# Text extracted for URL ID blackassign0065 and saved to blackassign0065.txt
# Text extracted for URL ID blackassign0066 and saved to blackassign0066.txt
# Text extracted for URL ID blackassign0067 and saved to blackassign0067.txt
# Text extracted for URL ID blackassign0068 and saved to blackassign0068.txt
# Text extracted for URL ID blackassign0069 and saved to blackassign0069.txt
# Text extracted for URL ID blackassign0070 and saved to blackassign0070.txt
# Text extracted for URL ID blackassign0071 and saved to blackassign0071.txt
# Text extracted for URL ID blackassign0072 and saved to blackassign0072.txt
# Text extracted for URL ID blackassign0073 and saved to blackassign0073.txt
# Text extracted for URL ID blackassign0074 and saved to blackassign0074.txt
# Text extracted for URL ID blackassign0075 and saved to blackassign0075.txt
# Text extracted for URL ID blackassign0076 and saved to blackassign0076.txt
# Text extracted for URL ID blackassign0077 and saved to blackassign0077.txt
# Text extracted for URL ID blackassign0078 and saved to blackassign0078.txt
# Text extracted for URL ID blackassign0079 and saved to blackassign0079.txt
# Text extracted for URL ID blackassign0080 and saved to blackassign0080.txt
# Text extracted for URL ID blackassign0081 and saved to blackassign0081.txt
# Text extracted for URL ID blackassign0082 and saved to blackassign0082.txt
# Text extracted for URL ID blackassign0083 and saved to blackassign0083.txt
# Text extracted for URL ID blackassign0084 and saved to blackassign0084.txt
# Text extracted for URL ID blackassign0085 and saved to blackassign0085.txt
# Text extracted for URL ID blackassign0086 and saved to blackassign0086.txt
# Text extracted for URL ID blackassign0087 and saved to blackassign0087.txt
# Text extracted for URL ID blackassign0088 and saved to blackassign0088.txt
# Text extracted for URL ID blackassign0089 and saved to blackassign0089.txt
# Text extracted for URL ID blackassign0090 and saved to blackassign0090.txt
# Text extracted for URL ID blackassign0091 and saved to blackassign0091.txt
# Text extracted for URL ID blackassign0092 and saved to blackassign0092.txt
# Text extracted for URL ID blackassign0093 and saved to blackassign0093.txt
# Text extracted for URL ID blackassign0094 and saved to blackassign0094.txt
# Text extracted for URL ID blackassign0095 and saved to blackassign0095.txt
# Text extracted for URL ID blackassign0096 and saved to blackassign0096.txt
# Text extracted for URL ID blackassign0097 and saved to blackassign0097.txt
# Text extracted for URL ID blackassign0098 and saved to blackassign0098.txt
# Text extracted for URL ID blackassign0099 and saved to blackassign0099.txt
# Text extracted for URL ID blackassign0100 and saved to blackassign0100.txt

# %%
#import shutil
#folder_path = '/content/sample_data/output_folder'
#shutil.rmtree(folder_path)

# %%
def count_sentences(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    sentences = nltk.sent_tokenize(content)
    return len(sentences)

# %%
def personal_pronouns(file_path):
  pronoun_pattern=r'\b(?:I|we|my|ours|us)\b'
  try:
    with open(file_path, 'r', encoding='utf-8') as file:
          paragraph = file.read()
    matches=re.findall(pronoun_pattern,paragraph,flags=re.IGNORECASE)
    matches=[match for match in matches if match.lower()!= 'us']
    return len(matches)
  except FileNotFoundError:
    return 0

# %%
def average_word_length(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()
        words = text.split()
        total_characters = sum(len(word) for word in words)
        total_words = len(words)
        if total_words > 0:
            average_word_length = total_characters / total_words
            return average_word_length
        else:
            return 0
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return 0

# %%
def average_words_per_sentence_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        paragraph = file.read()
    sentences = nltk.sent_tokenize(paragraph)
    total_words = sum(len(nltk.word_tokenize(sentence)) for sentence in sentences)
    if sentences:
        average_words = total_words / len(sentences)
        return average_words
    else:
        return 0

# %%
negative_path='/content/master_dictionary/negative-words.txt'
negative=[]
with open(negative_path,"r",encoding='latin-1')as file:
  file_content=file.read()
  negative=file_content.split()

# %%
positive_path='/content/master_dictionary/positive-words.txt'
positive=[]
with open(positive_path,"r",encoding='latin-1')as file:
  file_content=file.read()
  positive=file_content.split()

# %%
stopwords = open('StopWords.txt',encoding='latin-1').read()
stopwords=stopwords.split('\n')

# %%
def tokenize(j):
  filename=f"blackassign{j:04d}.txt"
  folder_path='/content/sample_data/output_folder'
  file_path=os.path.join(folder_path,filename)
  if os.path.exists(file_path):
    with open(file_path,encoding="utf-8")as file:
      text=file.read().lower()
      text=text.translate(str.maketrans("","",string.punctuation))
      tokenized_text=word_tokenize(text,"english")
      final_words=[word for word in tokenized_text if word not in stopwords]
    return final_words
  else:
    print(f"File not found:{filename}")
    return []

# %%
result_dict={}
for j in range(1,102):
  try:
    result_dict[f"text_{j}"]=tokenize(j)
    print(result_dict.get(f'text_{j}',[]))
  except KeyError:
    print(f"Key 'text_{j} not found.")
# Out:
# ['huge', 'development', 'dependence', 'people', 'technology', 'recent', 'years', 'development', 'ai', 'chatgpt', 'recent', 'years', 'normal', 'thing', 'fully', 'dependent', 'technology', '2040', 'information', 'technology', 'major', 'power', 'developing', 'nations', 'member', 'developing', 'nation', 'india', 'rapidly', 'growing', 'base', 'grown', 'cities', 'major', 'control', 'centres', 'information', 'technology', '2040rising', 'citiesnoidanoida', 'uttar', 'pradesh', 'delhi', 'emerging', 'sector', 'large', 'companies', 'google', 'microsoft', 'ibm', 'infosys', 'set', 'companies', 'noida', 'market', 'base', 'billions', 'dollars', 'great', 'job', 'boosting', 'national', 'economy', 'establishment', 'software', 'companies', 'made', 'noida', 'information', 'technology', 'hubgurgaongurgaon', 'haryana', 'emerging', 'hub', 'large', 'companies', 'google', 'microsoft', 'ibm', 'infosys', 'set', 'companies', 'gurgaon', 'market', 'base', 'billions', 'dollars', 'great', 'job', 'boosting', 'national', 'economybengalurubengaluru', 'called', 'hub', 'india', 'smart', 'city', 'large', 'companies', 'google', 'microsoft', 'ibm', 'infosys', 'set', 'companies', 'bengaluru', 'market', 'base', 'billions', 'dollars', 'great', 'job', 'boosting', 'national', 'economykolkatakolkata', 'west', 'bengal', 'emerging', 'major', 'hub', 'kolkata', 'saltlake', 'sector', '5', 'town', 'rajarhat', 'area', 'kolkata', 'major', 'hub', 'government', 'giving', 'software', 'companies', 'land', 'free', 'cost', 'set', 'companies', 'large', 'companies', 'google', 'microsoft', 'ibm', 'infosys', 'set', 'companies', 'kolkata', 'market', 'base', 'billions', 'dollars', 'great', 'job', 'boosting', 'national', 'economyimpact', 'economythere', 'huge', 'impact', 'rising', 'cities', 'economy', 'effects', 'aredemandthe', 'rising', 'cities', 'greatly', 'boost', 'economy', 'create', 'huge', 'demand', 'raw', 'materials', 'products', 'ready', 'huge', 'demand', 'people', 'toosupply–', 'supply', 'means', 'fulfilment', 'demand', 'large', 'highly', 'populous', 'country', 'india', 'demand', 'finished', 'products', 'cities', 'develop', 'companies', 'fulfil', 'desires', 'people', 'populous', 'country', 'india', 'cities', 'develop', 'companies', 'supply', 'finished', 'products', 'peoplemarket', 'marketis', 'place', 'economic
pollution', 'sensorbased', 'garbage', 'collection', 'improves', 'waste', 'management', 'resulting', 'cleaner', 'healthier', 'settingsto', 'major', 'player', 'world', 'economy', 'steps', 'crucial', 'relates', 'india', '’', 'ongoing', 'urbanization', 'development', '1970', '2018', 'population', 'indian', 'cities', 'predicted', 'expanded', '109', 'million', '460', 'million', 'fourfold', 'increasethe', 'nation', 'secondlargest', 'urban', 'population', 'world', 'predicted', '50', 'urban', 'population', 'share', '2050', 'adding', '416', 'million', 'residents', 'cities4', 'cities', 'centers', 'economic', 'growth', 'innovation', 'home', 'innovative', 'businesses', 'betterpaying', 'employment', 'important', 'institutions', 'kolkata', 'delhi', 'mumbai', 'chennaicities', 'foster', 'increased', 'productivity', 'routes', 'generally', 'asagglomeration', 'economies', 'permitting', 'close', 'contact', 'businesses', 'employees', 'theory', '’', 'main', 'consequence', 'businesses', 'bigger', 'andor', 'denser', 'cities', 'productive', 'year', '2035', 'urbanization', 'significant', 'impact', 'india', 'rest', 'world', 'india', 'boasts', 'thirdlargest', 'economy', 'world', 'china', 'united', 'states', 'period', 'china', 'exceeded', 'usa', 'terms', 'economic', 'size', 'india', 'surpassed', 'japan', 'claim', 'higher', 'place', 'india', '675', 'million', 'people', 'living', 'urbanized', 'cities', 'china', 'stunning', 'billion', 'people', 'living', 'urbanized', 'citiesurbanization', 'advantages', 'disadvantages', 'including', 'financial', 'expenditures', 'city', 'growth', 'result', 'possibilities', 'higher', 'standard', 'living', 'presents', 'difficulties', 'issues', 'rapid', 'urbanization', 'potential', 'deplete', 'resources', 'harm', 'environment', 'worsensocioeconomicinequities', 'depending', 'problems', 'solved', 'urbanization', 'favorable', 'negative', 'effectwith', 'half', 'world', '’', 'population', 'living', 'cities', 'urbanization', 'emerged', 'major', 'force', 'development', 'presents', 'fresh', 'difficulties', 'chances', 'reshaping', 'planet', 'life', 'unexpected', 'ways', 'future', 'whereartificial', 'intelligence', 'aiis', 'increasingly', 'pervasive', 'impact', 'parts', 'daily', 'lives', 'ushered', 'shift', 'urbanization', 'improved', 'living', 'conditions', 'economic', 'opportunities', 'calls', 'careful', 'management', 'sustainable', 'practices', 'guarantee', 'bright', 'prosperous',  ...
# ['introductionin', 'span', 'decades', 'internet', 'undergone', 'astounding', 'transformation', 'integral', 'part', 'lives', 'approach', 'year', '2035', 'demand', 'internet', 'connectivity', 'continues', 'surge', 'promising', 'revolutionize', 'communicate', 'interact', 'world', 'transformed', 'limited', 'communication', 'tool', 'allencompassing', 'global', 'network', 'shapes', 'daily', 'lives', 'hurtle', 'year', '2035', 'trajectory', 'internet', 'demand', 'profound', 'impact', 'communication', 'poised', 'reshape', 'foundations', 'connect', 'interact', 'article', 'delves', 'intricate', 'interplay', 'internet', 'demand', 'communication', 'dynamics', 'alternative', 'pathways', 'define', 'hyperconnected', 'futurethe', 'internet', '’', 'unstoppable', 'risethe', 'proliferation', 'smartphones', 'internet', 'things', 'iot', 'increasing', 'reliance', 'digital', 'services', 'driven', 'exponential', 'increase', 'internet', 'demand', 'surge', 'fueled', 'growing', 'faster', 'data', 'speeds', 'seamless', 'connectivity', 'realtime', 'access', 'information', 'services', 'digital', 'divide', 'narrows', 'individuals', 'communities', 'dependent', 'internet', 'education', 'healthcare', 'commerce', 'social', 'interactions', 'exponential', 'growth', 'internet', 'demand', 'defining', 'hallmark', 'digital', 'age', 'basic', 'web', 'browsing', 'streaming', 'highdefinition', 'content', 'realtime', 'remote', 'collaborations', 'demands', 'internet', 'infrastructure', 'surged', 'astronomically', 'demand', 'catalyzed', 'proliferation', 'smart', 'devices', 'internet', 'things', 'iot', 'insatiable', 'appetite', 'seamless', 'connectivityimpact', 'communicationsby', '2035', 'impact', 'rising', 'internet', 'demand', 'communication', 'multifaceted', 'notable', 'transformation', 'occur', 'realm', 'highspeed', 'connectivity', 'continued', 'development', '5g', 'technology', 'potentially', 'newer', 'innovations', 'enable', 'lightningfast', 'data', 'transfers', 'virtually', 'eliminating', 'lag', 'latency', 'redefine', 'remote', 'collaboration', 'gaming', 'experiences', 'realtime', 'communication', 'applications', 'surge', 'internet', 'demand', 'catalyze', 'evolution', 'virtual', 'augmented', 'reality', 'vrar', 'communication', 'technologies', 'enable', 'individuals', 'interact', 'physically', 'present', 'transcending', 'geographical', 'boundaries', 'enabling', 'immersive', 'experiences', 'teleconferencing', 'education', 'social', 'gatherings', 'engaging', 'interactive', 'internet', 'demand', 'continues', 'rise', 'realm', 'communication', 'set', 'monumental', 'transformation', 'highspeed', 'connectivity', 'driven', 'advancements', '5g', 'render', 'buffering', 'lag', 'virtually', 'obsolete', 'revolutionize', 'virtual', 'experiences', 'remote', 'work', 'digital', 'entertainment', 'fostering', 'sense', 'immediacy', 'presence', 'previously', 'unimaginable', 'integration', 'augmented', 'virtual', 'reality', 'arvr', 'reshape', 'communication', 'dynamics', 'immersive', 'virtual', 'meetings', 'interactive', 'entertainment', 'experiences', 'arvr', 'bridge', 'physical', 'distances', 'offer', 'dimension', 'engagementchallenges', 'strain', 'infrastructurehowever', 'exponential', 'increase', 'internet', 'demand', 'brings', 'set', 'challenges', 'existing', 'network', 'infrastructure', 'struggle', 'bandwidth', 'requirements', 'leading', 'congestion', 'reduced', 'quality', 'service', 'result', 'digital', 'divide', 'urban', 'rural', 'areas', 'underserved', 'communities', 'influx', 'data', 'traffic', 'raises', 'concerns', 'data', 'privacy', 'security', 'protecting', 'sensitive', 'information', 'cyber', 'threats', 'ensuring', 'integrity', 'personal', 'data', 'paramount', 'striking', 'balance', 'seamless', 'connectivity', 'robust', 'security', 'measures', 'complex', 'taskchallenges', 'hyperconnected', 'landscapethe', 'surge', 'internet', 'demand', 'promising', 'set', 'challenges', 'existing', 'network', 'infrastructure', 'struggle', 'accommodate', 'escalating', 'bandwidth', 'requirements', ...
# ['live', 'work', 'communicate', 'unquestionably', 'changed', 'result', 'rapid', 'evolution', 'technology', 'gain', 'digitization', 'leave', 'vulnerable', 'cybercrime', 'sinister', 'aspect', 'innovation', 'cybercrime', 'worrisome', 'issue', 'grown', 'time', 'year', '2040', 'impacts', 'expected', 'considerably', 'dangerous', 'article', 'examines', 'growing', 'problem', 'cybercrime', 'potentially', 'wide
ers', 'trend', 'accelerating', 'demand', 'online', 'connectivity2', 'evolution', 'communicationsthe', 'surge', 'internet', 'demand', 'revolutionize', 'traditional', 'communication', 'methods', 'voice', 'video', 'calling', 'seamless', 'highquality', 'due', 'widespread', 'implementation', '5g', 'networks', 'realtime', 'communication', 'immersive', 'interactive', 'enabling', 'virtual', 'meetings', 'conferences', 'rival', 'inperson', 'interactions', 'result', 'increased', 'productivity', 'reduced', 'travel', 'costs', 'businesses', 'individuals', 'alike3', 'role', 'ai', 'communicationsby', '2035', 'artificial', 'intelligence', 'ai', 'play', 'pivotal', 'role', 'optimizing', 'communication', 'experiences', 'aidriven', 'chatbots', 'virtual', 'assistants', 'ubiquitous', 'streamlining', 'customer', 'support', 'enhancing', 'user', 'experience', 'aipowered', 'language', 'translation', 'services', 'break', 'language', 'barriers', 'facilitating', 'crosscultural', 'communication', 'fostering', 'global', 'connections4', 'internet', 'things', 'iot', 'revolutionthe', 'internet', 'things', 'iot', 'reach', 'full', 'potential', '2035', 'myriad', 'interconnected', 'devices', 'shaping', 'communicate', 'interact', 'surroundings', 'smart', 'cities', 'utilize', 'iot', 'optimize', 'traffic', 'flow', 'reduce', 'energy', 'consumption', 'enhance', 'public', 'safety', 'iotenabled', 'healthcare', 'devices', 'revolutionize', 'telemedicine', 'enabling', 'remote', 'patient', 'monitoring', 'personalized', 'healthcare', 'services5', '5g', 'networks', 'enhanced', 'connectivitythe', 'deployment', '5g', 'networks', 'integral', 'meeting', 'escalating', 'internet', 'demand', '2035', '5g', 'infrastructure', 'widely', 'offering', 'unparalleled', 'speed', 'ultralow', 'latency', 'advancement', 'revolutionize', 'mobile', 'communication', 'enabling', 'realtime', 'data', 'transfer', 'augmented', 'reality', 'ar', 'virtual', 'reality', 'vr', 'experiences', 'go6', 'virtual', 'reality', 'vr', 'communicationvr', 'communication', 'mainstream', 'mode', 'interaction', '2035', 'virtual', 'meetings', 'social', 'gatherings', 'immersive', 'collaboration', 'spaces', 'redefine', 'concept', 'presence', 'enabling', 'individuals', 'corners', 'world', 'engage', 'physically', 'vr', 'significant', 'impact', 'industries', 'education', 'entertainment', 'professional', 'training7', 'challenge', 'cybersecuritythe', 'rise', 'internet', 'demand', 'amplify', 'risks', 'posed', 'cyber', 'threats', '2035', 'cybercriminals', 'employ', 'sophisticated', 'techniques', 'exploit', 'vulnerabilities', 'digital', 'infrastructure', 'governments', 'organizations', 'invest', 'heavily', 'cybersecurity', 'measures', 'safeguard', 'critical', 'data', 'protect', 'privacy', 'individuals8', 'technological', 'advancements', 'driving', 'communication', 'alternativesbeyond', 'internet', 'advancements', 'communication', 'alternatives', 'provide', 'viable', 'options', 'specific', 'cases', 'quantum', 'communication', 'promises', 'unparalleled', 'security', 'unbreakable',  ...
als', 'leverage', 'emerging', 'techniques', 'artificial', 'intelligence', 'machine', 'learning', 'enhance', 'attackscybercrime', 'evolved', 'significantly', 'past', 'decades', 'sophisticated', 'years', 'ways', 'cybercrime', 'expected', 'evolve', '2040the', 'rise', 'quantum', 'computing', 'quantum', 'computers', 'potential', 'break', 'encryption', 'algorithms', 'protect', 'data', 'make', 'easier', 'cybercriminals', 'steal', 'sensitive', 'information', 'financial', 'data', 'intellectual', 'propertythe', 'artificial', 'intelligence', 'ai', 'ai', 'cybercriminals', 'automate', 'tasks', 'sending', 'phishing', 'emails', 'generating', 'malware', 'future', 'ai', 'develop', 'sophisticated', 'attacks', 'target', 'specific', 'individuals', 'organizationsthe', 'growth', 'internet', 'things', 'iot', 'iot', 'connecting', 'billions', 'devices', 'internet', 'creates', 'attack', 'surface', 'cybercriminals', 'future', 'expect', 'attacks' ...
# ['abstractthe', 'rapid', 'development', 'internet', 'changed', 'ways', 'work', 'interact', 'communicate', 'demand', 'internet', 'connectivity', 'expected', 'reach', 'previously', 'unheardof', 'heights', 'year', '2035', 'person', 'planet', 'linked', 'article', 'discusses', 'developing', 'alternatives', 'reshape', 'digital', 'environment', 'india', 'world', 'effects', 'rise', 'internet', 'demand', 'communicationsthe', 'essay', 'emphasizes', 'digital', 'communication', 'channels', 'including', 'social', 'networking', 'platforms', 'video', 'conferencing', 'tools', 'instant', 'messaging', 'apps', 'overtake', 'traditional', 'communication', 'routes', 'future', 'telecommunications', 'sector', 'meet', 'growing', 'demand', 'shift', '5g', 'allowing', 'seamless', 'connectivity', 'iot', 'devices', 'building', 'foundation', 'smart', 'cities', 'driverless', 'vehiclesintroductionthe', 'interact', 'work', 'live', 'completely', 'changed', 'internet', 'demand', 'internet', 'grown', 'exponentially', 'inception', 'trend', 'expected', 'continue', 'coming', 'years', '2035', 'world', '’', 'population', 'connected', 'india', 'largest', 'economy', 'technology', 'hub', 'major', 'impact', 'development', 'digital', 'environment', 'worldwide', 'article', 'examines', 'demand', 'internet', 'growing', 'affects', 'communication', 'options', 'emerging', 'transform', 'digital', 'world', '2035an', 'ioe', 'ecosystem', 'created', 'integrating', 'ai', 'internet', 'personalizing', 'user', 'experiences', 'improving', 'services', 'shape', 'digital', 'future', 'foster', 'connected', 'secure', 'efficient', 'global', 'community', 'article', 'highlights', 'india', '’', 'role', 'technology', 'hubincrease', 'internet', 'demandthe', 'internet', 'influenced', 'facets', 'modern', 'culture', 'indispensable', 'component', 'internet', 'access', 'increased', 'dramatically', 'result', 'widespread', 'smartphones', 'iot', 'devices', 'technological', 'breakthroughs', 'anticipated', 'access', 'internet', '2035', 'location', 'due', 'exponential', 'rise', 'data', 'consumption', 'ensue', 'reliable', 'communications', 'infrastructure', 'needed', 'meet', 'rising', 'demandscommunications', 'effectour', 'communication', 'habits', 'change', 'dramatically', 'internet', 'usage', 'increases', 'consumers', 'prefer', 'fast', 'digital', 'communication', 'techniques', 'traditional', 'communication', 'channels', 'telephones', 'postal', 'services', 'continue', 'lose', 'prominence', 'communication', 'landscape', 'dominated', 'social', 'media', 'platforms', '
ain', 'disruptions', '80', 'believing', 'point', 'experience', 'impacts', 'result', 'covid19', 'disruptions', 'effective', 'shutdown', 'industrial', 'activity', 'china', 'ground', 'virus', 'presented', 'difficult', 'problems', 'manufacturing', 'firms', 'worldwide', 'imported', 'goods', 'invested', 'investors', 'set', 'significant', 'setbackseveral', 'experiments', 'carried', 'governments', 'globe', 'restrict', 'spread', 'pandemic', 'boris', 'johnson', 'introduced', 'herd', 'immunity', 'plan', 'united', 'kingdom', 'failure', 'mitigate', 'model', 'india', 'initially', 'stop', 'spread', 'covid19', 'virus', 'ultimate', 'model', 'countries', 'applying', 'hammer', 'dance', 'model', 'lockdown', 'model', 'estimated', 'bring', 'caseload', '2530', 'lockdown', 'model', 'basically', 'means', 'buying', 'time', 'prepare', 'vaccine', 'kill', 'virushowever', 'lockdown', 'critical', 'economic', 'consequences', 'add', 'burden', 'global', 'distress', 'explained', 'standard', 'macroeconomic', 'keynesian', 'model', 'lockdown', 'spread', 'disease', 'direct', 'negative', 'shock', 'aggregate', 'consumption', 'levels', 'exports', 'leads', 'contraction', 'aggregate', 'demand', 'leads', 'fall', 'market', 'rate', 'interest', 'aggregate', 'equilibrium', 'output', 'secondary', 'effect', 'commodity', 'market', 'investment', 'demand', 'function', 'increase', 'owing', 'fall', 'market', 'rate', 'interest', 'fall', 'owing', 'contraction', 'aggregate', 'demand', 'contraction', 'aggregate', 'demandside', 'generates', 'economic', 'slowdown', 'hand', 'restriction', 'workers', 'gathering', 'workplace', 'owing', 'lockdown', 'hurts', 'production', 'sectors', 'presence', 'physical', 'workers', 'note', 'software', 'financial', 'serviceproducing', 'sectors', 'exempted', 'negative', 'supply', 'shock', 'shortrun', 'mediumrun', 'works', 'easily', 'carried', 'based', '“', 'work', 'home', '”', 'anthem', 'reverse', 'migration', 'workers', 'indication', 'sharp', 'cut', 'production', 'activities', 'aggregate', 'supply', 'shock', 'leads', 'situation', 'stagflation', 'recent', 'announcements', 'reserve', 'bank', 'india', 'rbi', 'ease', 'liquidity', 'system', 'prove', 'counterproductive', 'provided', 'aggregate', 'supply', 'shock', 'escalation', 'demand', 'specifically', 'nontraded', 'products', 'adequate', 'increase', 'production', 'supply', 'result', 'inflation', 'words', 'supplyside', 'management', 'hand', 'hand', 'demandside', 'policies', 'policies', 'undertaken', 'national', 'level', 'government', 'conditions', 'improve', 'due', 'shocks', 'external', 'sector', 'trade', 'commodities', 'imports', 'banned', 'increase', 'economic', 'cost', 'production', 'import', 'substitutes', 'domes ...
# ['covid', '19', 'bought', 'world', 'knees', 'businesses', 'shut', 'travel', 'banned', 'schools', 'colleges', 'closed', 'observed', 'impeccable', 'amount', 'sorrow', 'despise', 'great', 'amount', 'mental', 'torture', 'destruction', 'situations', 'improving', 'lockdowns', 'lifted', 'fact', 'shunned', 'virus', 'long', 'term', 'impact', 'people', 'effects', 'felt', 'economically', 'physically', 'mentallywe', '’', 've', 'reading', 'articles', 'impact', 'covid', '19', 'economy', 'education', 'mental', 'health', 'aspect', 'topic', 'talked', 'impact', 'covid', '19', 'office', 'space', 'coworking', 'industries', 'obvious', 'offices', 'start', 'functioning', 'covid', 'period', 'hasn', '’', 'ended', 'means', 'social', 'distancing', 'offices', 'problem', 'lack', 'adequate', 'infrastructure', 'space', 'condition', 'coworking', 'industries', 'employees', 'companies', 'work', 'roofhowever', 'problems', 'obvious', 'people', 'haven', '’', 'thought', 'fact', 'people', 'fail', 'notice', 'understand', 'meaning', 'space', 'limited', 'infrastructural', 'space', 'measured', 'square', 'foot', 'square', 'meters', 'extends', 'metal', 'space', 'fact', 'space', 'minds', 'people', 'thoughts', 'opinionscoronavirus', 'left', 'big', 'scratch', 'country', 'car', 'repair', 'accident', 'country', 'repair', 'control', 'virus', 'unlike', 'car', 'country', 'require', 'large', 'amount', 'time', 'restored', 'stand', 'straight', 'supportneedless', 'economic', 'stability', 'country', 'hit', 'reason', 'problem', 'earnings', 'employers', 'reduce', 'subsequently', 'lead', 'drop', 'salary', 'employees', 'employees', 'preferred', 'bosses', 'receive', 'raise', 'regularly', 'subjected', 'unfair', 'treatment', 'made', 'amount', 'work', 'lower', 'salarypeople', 'tend', 'overlook', 'thin', 'line', 'exists', 'cooperation', 'competition', 'problem', 'doesn', '’', 'arise', 'situation', 'employee', 'paid', 'arises', 'people', 'start', 'compare', 'earnings', 'benefits', 'today', '’', 'world', 'people', 'money', 'top', 'priority', 'list', 'comparisons', 'play', 'important', 'role', 'performance', 'employees', 'companysince', 'exist', 'inequalities', 'partialities', 'companies', 'exist', 'sense', 'hatred', 'competition', 'employees', 'company', 'compete', 'position', 'raise', 'salary', 'beneficial', 'compel', 'employees', 'work', 'harder', 'bring', 'huge', 'losses', 'long', 'run', 'fact', 'employees', 'end', 'unethical', 'acts', 'make', 'impression', 'boss', '’', 'eyesmoreover', 'comparisons', 'employees', 'happen', '‘', 'employee', 'month', '’', 'ends', 'hated', 'employees', 'company', 'situation', 'arise', 'bluffing', 'pretending', 'employees', 'tend', 'show', 'work', 'hard', 'don', '’', 'practiced', 'showing', 'boss', 'working', 'chilling', 'rest', 'time', 'boss', 'home', 'sits', 'office', 'fact', 'employees', 'lose', 'interest', 'working', 'sense', 'repeated', 'partialities', 'inequalities', 'show', 'quitting', 'jobs', 'performing', 'bestsuch', 'situations', 'arise', 'companies', 'offices', 'employees', 'compete', 'attention', 'resources', 'great', 'impact', 'company', 'functioning', 'happen', 'thing', 'lack', 'office', 'mental', 'space', 'space', 'minds', 'people', 'working', 'office', 'cooperation', 'teamwork', 'ignorance', 'fact', 'things', 'eventually', 'timeanother', 'kind', 'industry', 'companies', 'affected', 'due', 'longlasting', 'impact', 'covid', '19', 'coworking', 'industry', 'offices', 'shortage', 'resources', 'income', 'people', 'maintenance', 'cost', 'born', 'infrastructure', 'rent', 'remain', 'employees', 'told', 'company', 'owners', 'exploit', 'resources', 'present', 'offices', 'fullest', 'compensate', 'losses', 'born', 'make', 'money', 'number', 'resources', 'case', 'competition', 'employees', 'companies', 'resources', 'benefits', 'sameif', 'situations', 'happen', 'occur', 'time', 'observe', 'scene', 'intracompany', 'intercompany', 'competition', 'personal', 'relations', 'employees', 'company', 'affected', 'due', 'comparison', 'competition', 'result', 'limited', ' ...
# ['handicrafts', 'art', 'making', 'crafts', 'hand', 'india', 'called', 'indian', 'handicrafts', 'ancient', 'india', 'people', 'lived', 'colonies', 'called', 'tribals', 'make', 'utility', 'items', 'daily', 'art', 'making', 'crafts', 'called', 'handicrafts', 'items', 'called', 'handicrafts', 'goodsfew', 'indian', 'handicrafts', 'followspashmina', 'shawlsbidriware', 'metal', 'handicraftcane', 'bamboo', 'handicraftszardozichikankarithe', 'visual', 'arts', 'art', 'forms', 'painting', 'drawing', 'printmaking', 'sculpture', 'ceramics', 'photography', 'video', 'filmmaking', 'design', 'crafts', 'architecture', 'artistic', 'disciplines', 'performing', 'arts', 'conceptual', 'art', 'textile', 'arts', 'involve', 'aspects', 'visual', 'arts', 'arts', 'types', 'included', 'visual', 'arts', 'applied', 'arts', 'industrial', 'design', 'graphic', 'design', 'fashion', 'design', 'interior', 'design', 'decorative', 'artroles', 'handicrafts', 'indian', 'economyindian', 'handicrafts', 'items', 'unique', 'impression', 'charm', 'immensely', 'big', 'largescale', 'industry', 'livelihood', '130', 'lakh', 'weavers', 'artisansindian', 'handicrafts', 'environment', 'friendly', 'low', 'energy', 'consumptionindian', 'handicraft', 'items', 'exported', 'generated', 'good', 'foreign', 'exchange', 'yearhandicraft', 'important', 'represents', 'culture', 'tradition', 'promotes', 'heritage', 'country', 'indigenous', 'materials', 'preserves', 'traditional', 'knowledge', 'talentsthese', 'days', 'handicraft', 'industry', 'plays', 'vital', 'role', 'rural', 'indian', 'sector', 'liberal', 'trade', 'export', 'indian', 'handloom', 'industry', 'alltime', 'highsome', 'key', 'facts', 'indian', 'handicrafts', 'industrythe', 'indian', 'handicraft', 'industry', 'showing', 'continuous', 'growth', 'rate', '20', 'yearmajor', 'parts', 'industry', 'operate', 'rural', 'semiurban', 'areas', 'country', 'potential', 'indian', 'international', 'markets', '67000', 'exporters', 'tap', 'marketaccording', 'national', 'census', 'handicrafts', 'undertaken', 'national', 'council', 'applied', 'economic', 'research', 'handicrafts', 'produced', 'year', 'rs', '26213', 'crorethis', 'industry', 'huge', 'employment', 'opportunities', 'artisans', 'include', 'women', 'people', 'belonging', 'backward', 'weaker', 'society', 'major', 'sources', 'income', 'therethe', 'indian', 'handicraft', 'industry', '100', 'billion', 'industry', 'worldwideindia', '’', 'contribution', 'world', 'market', '12the', 'total', 'exports', 'crafts', 'items', '–', 'rs', '1341292', 'croreindustry', '’', 'share', 'india', '’', 'exports', '–', '151', 'blackcoffer', 'insights', '18', 'harsh', 'gupta', 'pibm', 'pune']
# ['null']
# ['null']
# File not found:blackassign0101.txt
# []

# %%
def complex(word_list):
    cmu_dict = cmudict.dict()
    def is_complex(word):
        try:
            syllables = [len(phoneme) for phoneme in cmu_dict.get(word, [])]
            return sum(syllables) >= 2
        except IndexError:
            return False
    total_complex_words = sum(is_complex(word) for word in word_list)
    return total_complex_words

# %%
def count_syllables(word):
    if isinstance(word, str) and word.endswith(('es', 'ed')):
        return 0
    vowels = "aeiouAEIOU"
    count = 0
    is_vowel = False
    for char in word:
        if char in vowels:
            if not is_vowel:
                count += 1
                is_vowel = True
        else:
            is_vowel = False
    return count
def total_syllables_in_value(value):
    total_syllables = 0

    if isinstance(value, list):
        for word in value:
            total_syllables += count_syllables(word)

    return total_syllables

# %%
data=[]
count_of_words=[]
avg_syllable=[]
percentage_complex_words=[]
list_total_complex_words=[]
average_word_count_setence=[]
personal_pronouns_count=[]
average_word_len=[]
sentences_count=[]
word_count_before_cleaning=[]
complex_word_count=[]
word_count = 0
for j in range(1, 101):
    target_key = f'text_{j}'
    file_path = f'/content/sample_data/output_folder/blackassign{j:04d}.txt'
    with open(file_path, 'r', encoding='utf-8') as file:
      file_content = file.read()
      words = file_content.split()
      word_count_before = len(words)
      word_count_before_cleaning.append(word_count_before)
    if target_key in result_dict:
        values_for_key = result_dict[target_key]

        # Count of total words after tokenizing
        count_of_values_for_key = len(values_for_key)
        count_of_words.append(count_of_values_for_key)

        # Average syllables per word
        avg_syllables = total_syllables_in_value(values_for_key)
        avg_syllable.append(avg_syllables)

        # Percentage complex words
        word_list = result_dict.get(target_key, [])
        result = complex(word_list)
        complex_word_count.append(result)
        list_total_complex_words.append(result)

        if len(word_list) != 0:
            percentage_complex_words.append((result / len(word_list)) * 100)
        else:
            percentage_complex_words.append(0)

    else:
        print(f"{target_key} not found in the dictionary.")

    try:
        # Average word count in a sentence
        sentences = count_sentences(file_path)
        average_word_count_setence.append(sentences)

        # Personal pronouns count
        pronouns = personal_pronouns(file_path)
        personal_pronouns_count.append(pronouns)

        # Average word length
        word_length = average_word_length(file_path)
        average_word_len.append(word_length)

        # Sentence count
        sentences = count_sentences(file_path)
        sentences_count.append(sentences)

    except FileNotFoundError:
        print(f'file not found: {file_path}')
result_df=pd.DataFrame(data)
result_df.to_excel('Output.xlsx',index=False)

# %%
for j in range(1, 101):
    p = 0
    n = 0
    pol = 0
    sub = 0
    asl = 0
    pcw = 0
    fi = 0

    a=result_dict.get(f'text_{j}',[])
    for term in a:
        if term in positive:
            p += 1
        elif term in negative:
            n += 1

            pol = (p - n) / ((p + n) + 0.000001)
            sub = (p + n) / ((len(a)) + 0.000001)
            asl = word_count_before_cleaning[j] / sentences_count[j]
            pcw = list_total_complex_words[j] / word_count_before_cleaning[j]
            fi = 0.4 * (sentences_count[j] / percentage_complex_words[j])
            anwps=average_word_count_setence[j]
            cwc=complex_word_count[j]
            wc=word_count_before_cleaning[j]
            spw=avg_syllable[j]
            pp=personal_pronouns_count[j]
            awl=average_word_len[j]
    data.append({
        'URL': l[j],
        'POSITIVE SCORE': p,
        'NEGATIVE SCORE': n,
        'Polarity Score': pol,
        'Subjectivity Score': sub,
        'Average Sentence Length': asl,
        'Percentage of Complex words': pcw,
        'Fog Index': fi,
        'AVG NUMBER OF WORDS PER SENTENCE':anwps,
        'COMPLEX WORD COUNT':cwc,
        'WORD COUNT':wc,
        'SYLLABLE PER WORD':spw,
        'PERSONAL PRONOUNS':pp,
        'AVG WORD LENGTH':awl
    })

# Create a DataFrame and save it to an Excel file
result_df = pd.DataFrame(data)
result_df.to_excel('Output.xlsx', index=False)
